# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/Transformers/blob/main/Transformers%20Gen%20AI%20Book_Cover_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install accelerate
# !pip install sentence-transformers
# !pip install diffusers
# !pip install datasets
# !pip install faiss-cpu
# !pip install torch torchvision
# !pip install pandas
# !pip install scikit-learn
# !pip install pillow

# %%
#Input
 ↓
#Embedding
 ↓
#Positional Encoding
 ↓
#Encoder
 ↓
#Decoder
 ↓
#Output

# %%
#https://www.kaggle.com/datasets/jealousleopard/goodreadsbooks

# %%
import pandas as pd

data = pd.read_csv('/content/books.csv', on_bad_lines='skip')
data.head()

# %%
df = data[['title','authors']]

# %%
df = df.dropna()

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(
    "bert-base-uncased"
)

text = df.iloc[0]['title']

tokens = tokenizer.tokenize(text)

# %%
#I    Position 1
#love Position 2
#AI   Position 3

# %%
encoded = tokenizer(
    text,
    padding='max_length',
    truncation=True,
    max_length=32
)

print(encoded)

# %%
#EMBEDDINGS

from transformers import AutoModel

model = AutoModel.from_pretrained(
    "bert-base-uncased"
)

inputs = tokenizer(
    text,
    return_tensors="pt"
)

outputs = model(**inputs)

outputs.last_hidden_state.shape

# %%
attentions = outputs.attentions

# %%
model.config.num_attention_heads

# %%
from transformers import pipeline

# %%
classifier = pipeline(
    "text-classification",
    model="distilbert-base-uncased"
)

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="gpt2"
)

# %%
prompt = """
Write a fantasy book summary"""

result = generator(
    prompt,
    max_length=150
)

print(result[0]['generated_text'])

# %%
import transformers
print(transformers.__version__)

# %%
# !pip uninstall -y transformers
# !pip install transformers==4.52.4 sentencepiece accelerate -q

# %%
from transformers import pipeline

summarizer = pipeline(
    "summarization",
    model="t5-small"
)

# %%
book_description = """
A young warrior discovers an ancient dragon kingdom hidden beneath
the mountains. As dark forces begin to rise, he must unite rival
clans and unlock forgotten magic to save the realm.
"""

summary = summarizer(
    book_description,
    max_length=50,
    min_length=15,
    do_sample=False
)

print(summary[0]['summary_text'])

# %%
prompt = """
Generate a short book tagline:
"""

# %%
from sentence_transformers import SentenceTransformer

embedder = SentenceTransformer(
'all-MiniLM-L6-v2'
)

# %%
embeddings = embedder.encode(
df['title'].tolist()
)

# %%
import faiss
import numpy as np

dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(
dimension
)

index.add(
np.array(embeddings)
)

# %%
query = embedder.encode(
["Fantasy Dragon"]
)

D,I = index.search(
query,
5
)

print(I)

# %%
from transformers import CLIPProcessor
from transformers import CLIPModel

# %%
model = CLIPModel.from_pretrained(
"openai/clip-vit-base-patch32"
)

# %%
from transformers import ViTModel

# %%
vit = ViTModel.from_pretrained(
'google/vit-base-patch16-224'
)

# %%
from diffusers import AutoPipelineForText2Image
import torch

# %%
pipe = AutoPipelineForText2Image.from_pretrained(
"stabilityai/sdxl-turbo",
torch_dtype=torch.float32
)

# %%
prompt = """
Epic fantasy novel cover,
ancient dragon kingdom,
cinematic lighting,
professional book cover,
high quality
"""

image = pipe(
prompt,
num_inference_steps=1
).images[0]

image.save(
"book_cover.png"
)

# %%
image
